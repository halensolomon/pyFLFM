# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib widget
from matplotlib.colors import LogNorm

# %%
# %matplotlib widget

# %%
plt.close()
plt.imshow(torch.load('./0itr5.pt')[13,:,:])
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
