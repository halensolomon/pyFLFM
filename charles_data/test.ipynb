# %%
import torch
import matplotlib.pyplot as plt
import numpy as np
import math
from matplotlib.colors import LogNorm
import cv2 as cv

# %%
# %matplotlib widget

# %%
data = torch.load('./undeformed/0.pt')

# %%
for i in range(len(data[:,0,0])):
    cv.imwrite(f'./undeformed/{i}.tif', data[i,:,:].cpu().numpy())

# %%
for i in range(len())

# %%
plt.close()
plt.imshow(torch.clamp(torch.load(r'./batch1/set13_img169/0.pt')[10,:,:].squeeze(0), max = 512), cmap='gray', vmin=40, vmax = 100)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# 2521, 4222, 4097, 4233 # forward
# 2080, 4250, 4126, 4200 # image

# %%
import torchvision as tv

# %%
H_2n = torch.load(r'./H_2n.pt')
Ht_2n = torch.load(r'./Ht_2n.pt')

# %%
resize = tv.transforms.Resize((10000,10000))

# %%
torch.save(resize(H_2n)[:,904:9096,904:9096], r'./H_2n_rescaled.pt')
torch.save(resize(Ht_2n)[:,904:9096,904:9096], r'./Ht_2n_rescaled.pt')

# %%
plt.close()
plt.imshow(torch.abs(10000*(resized_psf[904:9096, 904:9096]) - torch.load(r'./deformed_2n.pt')[0,:,:]))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
cv.imwrite('./deformed_1_20_13.tif', torch.load(r'./deformed_1/0.pt')[13,:,:].numpy())
# Out:
# True
